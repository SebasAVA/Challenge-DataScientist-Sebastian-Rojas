# %% [markdown]
# IDEAS:
# -MAPA
# -STREAMLIT
# -README
# -Prediccion de vuelos actuales
#
# ANALIZAR DONE
# LIMPIAMOS

# %% [markdown]
# ## Import libraries and packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading CSV  with pandas

# %%
scl_flt = pd.read_csv("dataset_SCL.csv")
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_13672\2756499070.py:1: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   scl_flt = pd.read_csv("dataset_SCL.csv")

# %%
scl_flt.head()
# Out:
#                Fecha-I Vlo-I Ori-I Des-I Emp-I              Fecha-O Vlo-O  \
# 0  2017-01-01 23:30:00   226  SCEL  KMIA   AAL  2017-01-01 23:33:00   226
# 1  2017-01-02 23:30:00   226  SCEL  KMIA   AAL  2017-01-02 23:39:00   226
# 2  2017-01-03 23:30:00   226  SCEL  KMIA   AAL  2017-01-03 23:39:00   226
# 3  2017-01-04 23:30:00   226  SCEL  KMIA   AAL  2017-01-04 23:33:00   226
# 4  2017-01-05 23:30:00   226  SCEL  KMIA   AAL  2017-01-05 23:28:00   226
#
#   Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO              OPERA  \
# 0  SCEL  KMIA   AAL    1    1  2017    Domingo         I  American Airlines
# 1  SCEL  KMIA   AAL    2    1  2017      Lunes         I  American Airlines
# 2  SCEL  KMIA   AAL    3    1  2017     Martes         I  American Airlines
# 3  SCEL  KMIA   AAL    4    1  2017  Miercoles         I  American Airlines
# 4  SCEL  KMIA   AAL    5    1  2017     Jueves         I  American Airlines
#
#    SIGLAORI SIGLADES
# 0  Santiago    Miami
# 1  Santiago    Miami
# 2  Santiago    Miami
# 3  Santiago    Miami
# 4  Santiago    Miami

# %% [markdown]
# # Analysis of categorical variables

# %%
scl_flt[["Vlo-I","Vlo-O","Ori-I","Ori-O","Des-I","Des-O","SIGLAORI","SIGLADES","Emp-I","Emp-O","OPERA","TIPOVUELO","DIANOM"]].describe()
# Out:
#         Vlo-I  Vlo-O  Ori-I  Ori-O  Des-I  Des-O  SIGLAORI      SIGLADES  \
# count   68206  68205  68206  68206  68206  68206     68206         68206
# unique    750    866      1      1     64     63         1            62
# top       174    174   SCEL   SCEL   SCFA   SCFA  Santiago  Buenos Aires
# freq      686    649  68206  68206   5787   5786     68206          6335
#
#         Emp-I  Emp-O        OPERA TIPOVUELO   DIANOM
# count   68206  68206        68206     68206    68206
# unique     30     32           23         2        7
# top       LAN    LAN  Grupo LATAM         N  Viernes
# freq    37611  20988        40892     36966    10292

# %%
print("FECHA-I")
print(scl_flt["Fecha-I"].max())
print(scl_flt["Fecha-I"].min())
print("FECHA-O")
print(scl_flt["Fecha-O"].max())
print(scl_flt["Fecha-O"].min())
# Out:
# FECHA-I
# 2017-12-31 23:55:00
# 2017-01-01 00:15:00
# FECHA-O
# 2018-01-01 00:12:00
# 2017-01-01 00:04:00

# %% [markdown]
# As we can see, variables such as the number of flight ```Vlo-I``` ,```Vlo-O```, have different values in the description. The flight number has more unique values on the actual operated flights and the top value is the flight **174** on both variables.
#
# Something similar is happening with the variables related with the destination ```Des-I``` ,```Des-O```, in which the number of unique values of the operated destination is less than the schedule values, in this case the most frequent destination is **SCFA** that correspond to the airport of Antofagasta in Chile (ICAO airport code), base on this we want to check the type of flight with the variable ```TIPOVUELO``` and we can check that the 54% of the flight are national flights.
#
# Another interesting and disruptive thing that we can notice is that the variable ```SIGLADES``` that is the name of the city of destination does not correspond with the ICAO code airport of the variable ```Des-O``` or ```Des-I```, and as I said before the most common destination is Antofagasta, but in this case Buenos Aires in Argentina is the most frequent city of destination, so we need to check why this is happening with this variable.
#
#
# With the code of the airline ```Emp-I``` ```Emp-O``` and the name ```OPERA``` we can notice that there are less names of airlines that codes, this because the airline can operate with different codes, and we can check in the next cells. Grupo LATAM with the callsign of LAN have the most frequent operation in SCEL.
#
# Finally the data is composed for 68206 records. with dates from january of 2017 to december of 2017 and as is expected the column of the operated have the max data the first of January

# %% [markdown]
# ## Cleaning and anlysis

# %% [markdown]
# ### Flight Number

# %% [markdown]
# No hay NA, transformamos la vairable the Operados, luego la de inicial, se mira cuales son los remannte que permanecen desiguales

# %%
scl_flt.isna().sum()
# Out:
# Fecha-I      0
# Vlo-I        0
# Ori-I        0
# Des-I        0
# Emp-I        0
# Fecha-O      0
# Vlo-O        1
# Ori-O        0
# Des-O        0
# Emp-O        0
# DIA          0
# MES          0
# AÑO          0
# DIANOM       0
# TIPOVUELO    0
# OPERA        0
# SIGLAORI     0
# SIGLADES     0
# dtype: int64

# %%
scl_flt[scl_flt.apply(lambda x: x['Vlo-I'] != x['Vlo-O'], axis = 1)][["Vlo-I","Vlo-O"]].value_counts().head(10)
# Out:
# Vlo-I  Vlo-O
# 170    170.0    43
# 168    168.0    43
# 164    164.0    42
# 162    162.0    41
# 150    150.0    40
# 174    174.0    37
# 156    156.0    36
# 172    172.0    32
# 166    166.0    32
# 231    231.0    31
# dtype: int64

# %%
scl_flt["Vlo-Ope"]=scl_flt.apply(lambda x: str(x['Vlo-O']).replace(".0",""), axis = 1)

# %%
scl_flt[scl_flt.apply(lambda x: x['Vlo-I'] != x['Vlo-Ope'], axis = 1)][["Vlo-I","Vlo-Ope"]].describe()
# Out:
#         Vlo-I Vlo-Ope
# count    2789    2789
# unique    237     240
# top       281     281
# freq       54      54

# %%
scl_flt["Vlo-Ini"]=scl_flt["Vlo-I"].astype(str)

# %%
scl_flt[scl_flt.apply(lambda x: x['Vlo-I'] != x['Vlo-Ini'], axis = 1)][["Vlo-I","Vlo-Ini"]].value_counts().head(5)
# Out:
# Vlo-I  Vlo-Ini
# 281    281        54
# 50     50         50
# 704    704        41
# 572    572        31
# 340    340        31
# dtype: int64

# %%
scl_flt[["Vlo-I","Vlo-Ini","Vlo-O","Vlo-Ope"]].describe()
# Out:
#         Vlo-I Vlo-Ini  Vlo-O Vlo-Ope
# count   68206   68206  68205   68206
# unique    750     584    866     609
# top       174     174    174     174
# freq      686     686    649     686

# %%
scl_flt[scl_flt.apply(lambda x: x['Vlo-Ini'] != x['Vlo-Ope'], axis = 1)][["Des-I","Des-O","Vlo-Ini","Vlo-Ope"]].value_counts()
# Out:
# Des-I  Des-O  Vlo-Ini  Vlo-Ope
# SAEZ   SAEZ   4501     1001       19
#               4503     1003       11
#                        1303        5
# SPJC   SPJC   702      700         3
# SAEZ   SAEZ   7811     1101        3
#                                   ..
#               7813     1071        1
# KATL   KATL   146      9858        1
# SCAT   SCAT   114      114R        1
# SCDA   SCDA   110      33          1
# SUMU   SUMU   989P     989         1
# Length: 73, dtype: int64

# %% [markdown]
# ### Destination

# %% [markdown]
# Los vuelos simplemente cambiaron de destino debido a alguna razon durante el vuelo, tiene sentido ya que puede ser el aeropuerto alterno y sha
# 2 casos no terminan en el mismo pais pero su aeropuerto alterno se encuentra en otro pais, ecuador, brasil
# 2 dado el codigo ICAO no corresponden al mismo pais pero realmente si ya que estos paises tienen una composicion de codigo diferente a la de sur america Australia y estaods unidos

# %%
scl_flt[scl_flt.apply(lambda x: x['Des-I'] != x['Des-O'], axis = 1)][["Des-I","Des-O"]].value_counts()
# Out:
# Des-I  Des-O
# SCTE   SCQP     5
# SABE   SAEZ     4
# SCBA   SCTE     4
# SAEZ   SABE     3
# KIAH   KIAD     1
# KJFK   KMIA     1
# SARI   SBFI     1
# SBGR   SBGL     1
# SCCI   SCTE     1
# SCFA   SCCF     1
# SCIE   SCQP     1
#        SCTE     1
# SCTE   SCCI     1
# SEGU   SABE     1
# SEQU   SEQM     1
# YSSY   YMML     1
# dtype: int64

# %%
diffDest = scl_flt[scl_flt.apply(lambda x: x['Des-I'] != x['Des-O'], axis = 1)][["Des-I","Des-O"]]

# %%
diffDest['Des-I']=diffDest['Des-I'].str.slice(0, 2)
diffDest['Des-O']=diffDest['Des-O'].str.slice(0, 2)

# %%
diffDest['Des-I']== diffDest['Des-O']
# Out:
# 1397      True
# 7290      True
# 7520      True
# 8456      True
# 12787     True
# 12823     True
# 16169    False
# 16937    False
# 18293     True
# 20444     True
# 24569     True
# 25419     True
# 25422     True
# 25492     True
# 33166     True
# 37162     True
# 38094     True
# 38135     True
# 38136     True
# 39265     True
# 42112     True
# 55144     True
# 61463     True
# 62651    False
# 67599     True
# 67600     True
# 67601     True
# 67697    False
# dtype: bool

# %% [markdown]
# El conteo por aeropuertos nos muestra que solo un aeropuerto atiende antofagasta mientras que a Buenos aires tiene ezeia y el aeroparque
# Al final la ciudad corresponde al aeropuerto actualemente operado, confirmando lo que antes se mostro

# %%
scl_flt[scl_flt["SIGLADES"]=="Buenos Aires"].pivot_table(values = "Fecha-I", index = ["Des-I","Des-O"], columns = "SIGLADES",  aggfunc = "count")
# Out:
# SIGLADES     Buenos Aires
# Des-I Des-O
# SABE  SABE           3090
#       SAEZ              4
# SAEZ  SABE              3
#       SAEZ           3237
# SEGU  SABE              1

# %% [markdown]
# ### Airline

# %%
scl_flt["Emp-I"].value_counts()
# Out:
# LAN    37611
# SKU    14298
# TAM     3049
# ARG     1949
# CMP     1850
# LAW     1574
# AVA     1152
# JAT     1095
# GLO      806
# AAL      757
# ACA      565
# IBE      362
# AFR      358
# DAL      358
# AMX      351
# UAL      335
# ONE      279
# AZA      259
# KLM      251
# LAP      216
# BAW      205
# QFU      195
# JMR      100
# LRC       92
# AUT       74
# PUE       49
# LXP        9
# LPE        4
# DSM        2
# LNE        1
# Name: Emp-I, dtype: int64

# %%
scl_flt["Emp-O"].value_counts()
# Out:
# LAN    20988
# LXP    14558
# SKU    14298
# TAM     3046
# ARG     1946
# CMP     1850
# JMR     1647
# LPE     1214
# JAT     1095
# AVA      885
# GLO      806
# AAL      757
# ACA      565
# DSM      493
# LNE      374
# IBE      362
# AFR      358
# DAL      358
# LRC      357
# AMX      351
# UAL      335
# ONE      279
# AZA      259
# KLM      251
# LAP      219
# BAW      205
# QFA      195
# AUT       77
# PUE       49
# 56R       17
# 48O       10
# TPU        2
# Name: Emp-O, dtype: int64

# %%
scl_flt[scl_flt["OPERA"]=="Grupo LATAM"]["Emp-I"].value_counts().sum()
# Out:
# 40892

# %%
scl_flt[scl_flt["OPERA"]=="Grupo LATAM"]["Emp-O"].value_counts().sum()
# Out:
# 40892

# %%
scl_flt[scl_flt["OPERA"]=="Grupo LATAM"].pivot_table(index=["Emp-I","Emp-O"], columns ="OPERA", values = "Des-I", aggfunc = "count")
# Out:
# OPERA        Grupo LATAM
# Emp-I Emp-O
# DSM   DSM              2
# LAN   DSM            491
#       LAN          20988
#       LNE            373
#       LPE           1210
#       LXP          14549
# LAP   LAP            216
# LNE   LNE              1
# LPE   LPE              4
# LXP   LXP              9
# TAM   LAP              3
#       TAM           3046

# %%
scl_flt[scl_flt["OPERA"]=="Grupo LATAM"].pivot_table(index=["Emp-I","Emp-O"], columns ="OPERA", values = "Des-I", aggfunc = "count")
# Out:
# OPERA        Grupo LATAM
# Emp-I Emp-O
# DSM   DSM              2
# LAN   DSM            491
#       LAN          20988
#       LNE            373
#       LPE           1210
#       LXP          14549
# LAP   LAP            216
# LNE   LNE              1
# LPE   LPE              4
# LXP   LXP              9
# TAM   LAP              3
#       TAM           3046

# %%
scl_flt[scl_flt["OPERA"]!="Grupo LATAM"]["OPERA"].value_counts()
# Out:
# Sky Airline                 14298
# Aerolineas Argentinas        1949
# Copa Air                     1850
# Latin American Wings         1674
# Avianca                      1152
# JetSmart SPA                 1095
# Gol Trans                     806
# American Airlines             757
# Air Canada                    565
# Iberia                        362
# Delta Air                     358
# Air France                    358
# Aeromexico                    351
# United Airlines               335
# Oceanair Linhas Aereas        279
# Alitalia                      259
# K.L.M.                        251
# British Airways               205
# Qantas Airways                195
# Lacsa                          92
# Austral                        74
# Plus Ultra Lineas Aereas       49
# Name: OPERA, dtype: int64

# %% [markdown]
# The numeric values that we can see on the DataFrame are linked with the date, so basically does not provide to us more information about the things that we already have.

# %% [markdown]
# ## New Variables

# %%
scl_flt["Date-I"] = pd.to_datetime(scl_flt["Fecha-I"])
scl_flt["Date-O"] = pd.to_datetime(scl_flt["Fecha-O"])

# %%
scl_flt["temporada_alta"]=(scl_flt["Date-I"]<="2017-03-03")+(scl_flt["Date-I"]>"2017-07-15") & (scl_flt["Date-I"]<"2017-07-31")+(scl_flt["Date-I"]>"2017-09-11") & (scl_flt["Date-I"]<"2017-09-30")+(scl_flt["Date-I"]>"2017-12-15")

# %%
scl_flt["temporada_alta"]= scl_flt["temporada_alta"]*1

# %%
scl_flt["dif_min"]=((scl_flt["Date-O"]-scl_flt["Date-I"])/pd.Timedelta(minutes=1)).astype(int)

# %%
scl_flt["atraso_15"]=(scl_flt["dif_min"]>15)*1

# %%
scl_flt["HOUR"]=scl_flt["Date-I"].apply(lambda x: x.hour)

# %%
scl_flt["periodo_dia"] = "noche"

# %%
scl_flt.loc[(scl_flt["HOUR"]>=5) & (scl_flt["HOUR"]<12),["periodo_dia"]] = "manana"

# %%
scl_flt.loc[(scl_flt["HOUR"]>=12) & (scl_flt["HOUR"]<19),["periodo_dia"]] = "tarde"

# %%
scl_flt[["temporada_alta","dif_min","atraso_15","periodo_dia"]].to_csv("synthetic_features.csv",index=False)

# %% [markdown]
# ## Delayed flights rate

# %% [markdown]
# Empezamos por lo basico, descripcion de metricas estadisticas....
# Debo evalaur por aerolinea, temporada, mes, tipo de vuelo

# %%
scl_flt["dif_min"].describe()
# Out:
# count    68206.000000
# mean         9.110855
# std         19.313387
# min        -14.000000
# 25%         -1.000000
# 50%          4.000000
# 75%         12.000000
# max        161.000000
# Name: dif_min, dtype: float64

# %%
def highlight(val):
    if(val>=15):
        color = 'red'
    elif(val<10):
        color = 'green'
    else:
        color = 'black'
    return 'color: %s' % color

# %%
scl_flt.pivot_table(values = "dif_min",columns="TIPOVUELO",aggfunc=(np.mean))
# Out:
# TIPOVUELO          I        N
# dif_min    10.638892  7.81951

# %%
scl_flt.pivot_table(values = "dif_min",index="OPERA",columns="TIPOVUELO",aggfunc=(np.mean)).style.applymap(highlight)
# Out:
# <style type="text/css">
# #T_2e379_row0_col0, #T_2e379_row0_col1, #T_2e379_row1_col1, #T_2e379_row2_col1, #T_2e379_row3_col1, #T_2e379_row4_col1, #T_2e379_row5_col1, #T_2e379_row6_col1, #T_2e379_row7_col0, #T_2e379_row7_col1, #T_2e379_row8_col1, #T_2e379_row9_col1, #T_2e379_row10_col1, #T_2e379_row11_col0, #T_2e379_row11_col1, #T_2e379_row12_col0, #T_2e379_row13_col1, #T_2e379_row15_col1, #T_2e379_row16_col1, #T_2e379_row18_col1, #T_2e379_row19_col1, #T_2e379_row20_col1, #T_2e379_row22_col1 {
#   color: black;
# }
# #T_2e379_row1_col0, #T_2e379_row3_col0, #T_2e379_row4_col0, #T_2e379_row5_col0, #T_2e379_row6_col0, #T_2e379_row8_col0, #T_2e379_row9_col0, #T_2e379_row10_col0, #T_2e379_row12_col1, #T_2e379_row13_col0, #T_2e379_row14_col1, #T_2e379_row15_col0, #T_2e379_row16_col0, #T_2e379_row18_col0, #T_2e379_row21_col0, #T_2e379_row21_col1, #T_2e379_row22_col0 {
#   color: green;
# }
# #T_2e379_row2_col0, #T_2e379_row14_col0, #T_2e379_row17_col0, #T_2e379_row17_col1, #T_2e379_row19_col0, #T_2e379_row20_col0 {
#   color: red;
# }
# </style>
# <table id="T_2e379">
#   <thead>
#     <tr>
#       <th class="index_name level0" >TIPOVUELO</th>
#       <th id="T_2e379_level0_col0" class="col_heading level0 col0" >I</th>
#       <th id="T_2e379_level0_col1" class="col_heading level0 col1" >N</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >OPERA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e379_level0_row0" class="row_heading level0 row0" >Aerolineas Argentinas</th>
#       <td id="T_2e379_row0_col0" class="data row0 col0" >10.004618</td>
#       <td id="T_2e379_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row1" class="row_heading level0 row1" >Aeromexico</th>
#       <td id="T_2e379_row1_col0" class="data row1 col0" >-2.495726</td>
#       <td id="T_2e379_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row2" class="row_heading level0 row2" >Air Canada</th>
#       <td id="T_2e379_row2_col0" class="data row2 col0" >22.909735</td>
#       <td id="T_2e379_row2_col1" class="data row2 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row3" class="row_heading level0 row3" >Air France</th>
#       <td id="T_2e379_row3_col0" class="data row3 col0" >1.399441</td>
#       <td id="T_2e379_row3_col1" class="data row3 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row4" class="row_heading level0 row4" >Alitalia</th>
#       <td id="T_2e379_row4_col0" class="data row4 col0" >5.293436</td>
#       <td id="T_2e379_row4_col1" class="data row4 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row5" class="row_heading level0 row5" >American Airlines</th>
#       <td id="T_2e379_row5_col0" class="data row5 col0" >0.277411</td>
#       <td id="T_2e379_row5_col1" class="data row5 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row6" class="row_heading level0 row6" >Austral</th>
#       <td id="T_2e379_row6_col0" class="data row6 col0" >6.608108</td>
#       <td id="T_2e379_row6_col1" class="data row6 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row7" class="row_heading level0 row7" >Avianca</th>
#       <td id="T_2e379_row7_col0" class="data row7 col0" >11.131944</td>
#       <td id="T_2e379_row7_col1" class="data row7 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row8" class="row_heading level0 row8" >British Airways</th>
#       <td id="T_2e379_row8_col0" class="data row8 col0" >7.560976</td>
#       <td id="T_2e379_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row9" class="row_heading level0 row9" >Copa Air</th>
#       <td id="T_2e379_row9_col0" class="data row9 col0" >0.214054</td>
#       <td id="T_2e379_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row10" class="row_heading level0 row10" >Delta Air</th>
#       <td id="T_2e379_row10_col0" class="data row10 col0" >0.114525</td>
#       <td id="T_2e379_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row11" class="row_heading level0 row11" >Gol Trans</th>
#       <td id="T_2e379_row11_col0" class="data row11 col0" >11.911911</td>
#       <td id="T_2e379_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row12" class="row_heading level0 row12" >Grupo LATAM</th>
#       <td id="T_2e379_row12_col0" class="data row12 col0" >11.938247</td>
#       <td id="T_2e379_row12_col1" class="data row12 col1" >7.688329</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row13" class="row_heading level0 row13" >Iberia</th>
#       <td id="T_2e379_row13_col0" class="data row13 col0" >4.276243</td>
#       <td id="T_2e379_row13_col1" class="data row13 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row14" class="row_heading level0 row14" >JetSmart SPA</th>
#       <td id="T_2e379_row14_col0" class="data row14 col0" >23.333333</td>
#       <td id="T_2e379_row14_col1" class="data row14 col1" >7.354454</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row15" class="row_heading level0 row15" >K.L.M.</th>
#       <td id="T_2e379_row15_col0" class="data row15 col0" >1.310757</td>
#       <td id="T_2e379_row15_col1" class="data row15 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row16" class="row_heading level0 row16" >Lacsa</th>
#       <td id="T_2e379_row16_col0" class="data row16 col0" >4.880435</td>
#       <td id="T_2e379_row16_col1" class="data row16 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row17" class="row_heading level0 row17" >Latin American Wings</th>
#       <td id="T_2e379_row17_col0" class="data row17 col0" >29.863198</td>
#       <td id="T_2e379_row17_col1" class="data row17 col1" >15.921384</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row18" class="row_heading level0 row18" >Oceanair Linhas Aereas</th>
#       <td id="T_2e379_row18_col0" class="data row18 col0" >6.340502</td>
#       <td id="T_2e379_row18_col1" class="data row18 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row19" class="row_heading level0 row19" >Plus Ultra Lineas Aereas</th>
#       <td id="T_2e379_row19_col0" class="data row19 col0" >31.714286</td>
#       <td id="T_2e379_row19_col1" class="data row19 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row20" class="row_heading level0 row20" >Qantas Airways</th>
#       <td id="T_2e379_row20_col0" class="data row20 col0" >26.835897</td>
#       <td id="T_2e379_row20_col1" class="data row20 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row21" class="row_heading level0 row21" >Sky Airline</th>
#       <td id="T_2e379_row21_col0" class="data row21 col0" >9.886429</td>
#       <td id="T_2e379_row21_col1" class="data row21 col1" >7.686293</td>
#     </tr>
#     <tr>
#       <th id="T_2e379_level0_row22" class="row_heading level0 row22" >United Airlines</th>
#       <td id="T_2e379_row22_col0" class="data row22 col0" >-1.856716</td>
#       <td id="T_2e379_row22_col1" class="data row22 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
scl_flt.pivot_table(values = "dif_min",columns="DIANOM",aggfunc=(np.mean))
# Out:
# DIANOM    Domingo   Jueves     Lunes    Martes  Miercoles    Sabado    Viernes
# dif_min  7.930788  9.52112  9.980653  8.324777   8.540835  8.315014  10.891469

# %%
scl_flt.pivot_table(values = "dif_min",index="periodo_dia",aggfunc=(np.mean))
# Out:
#               dif_min
# periodo_dia
# manana       8.061534
# noche        9.694086
# tarde        9.757155

# %%
scl_flt.pivot_table(values = "dif_min",index="temporada_alta",columns="MES",aggfunc=(np.mean))
# Out:
# MES                   1         2         3         4         5         6   \
# temporada_alta
# 0                    NaN       NaN  5.660711  5.773506  7.521756  8.542461
# 1               7.769646  7.537853  7.020566       NaN       NaN       NaN
#
# MES                    7         8         9          10        11         12
# temporada_alta
# 0               14.691698  8.616818  9.933929  11.295922  9.342763  10.363101
# 1               16.011654       NaN  7.693356        NaN       NaN  13.088261

# %%
scl_flt.pivot_table(values = "dif_min",index="OPERA",columns="periodo_dia",aggfunc=(np.mean)).style.applymap(highlight)
# Out:
# <style type="text/css">
# #T_0586e_row0_col0, #T_0586e_row1_col1, #T_0586e_row3_col2, #T_0586e_row4_col0, #T_0586e_row4_col2, #T_0586e_row5_col1, #T_0586e_row6_col1, #T_0586e_row6_col2, #T_0586e_row7_col0, #T_0586e_row7_col1, #T_0586e_row8_col2, #T_0586e_row9_col0, #T_0586e_row9_col1, #T_0586e_row9_col2, #T_0586e_row10_col1, #T_0586e_row11_col0, #T_0586e_row11_col1, #T_0586e_row12_col0, #T_0586e_row12_col2, #T_0586e_row13_col0, #T_0586e_row13_col2, #T_0586e_row14_col0, #T_0586e_row14_col1, #T_0586e_row14_col2, #T_0586e_row15_col0, #T_0586e_row15_col2, #T_0586e_row16_col0, #T_0586e_row18_col1, #T_0586e_row18_col2, #T_0586e_row21_col0, #T_0586e_row21_col2, #T_0586e_row22_col1 {
#   color: green;
# }
# #T_0586e_row0_col1, #T_0586e_row0_col2, #T_0586e_row1_col0, #T_0586e_row3_col0, #T_0586e_row3_col1, #T_0586e_row4_col1, #T_0586e_row5_col0, #T_0586e_row5_col2, #T_0586e_row6_col0, #T_0586e_row8_col0, #T_0586e_row8_col1, #T_0586e_row12_col1, #T_0586e_row13_col1, #T_0586e_row15_col1, #T_0586e_row16_col1, #T_0586e_row16_col2, #T_0586e_row18_col0, #T_0586e_row19_col0, #T_0586e_row20_col0, #T_0586e_row20_col1, #T_0586e_row21_col1, #T_0586e_row22_col0 {
#   color: black;
# }
# #T_0586e_row1_col2, #T_0586e_row2_col0, #T_0586e_row2_col1, #T_0586e_row2_col2, #T_0586e_row7_col2, #T_0586e_row10_col0, #T_0586e_row10_col2, #T_0586e_row11_col2, #T_0586e_row17_col0, #T_0586e_row17_col1, #T_0586e_row17_col2, #T_0586e_row19_col1, #T_0586e_row19_col2, #T_0586e_row20_col2, #T_0586e_row22_col2 {
#   color: red;
# }
# </style>
# <table id="T_0586e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >periodo_dia</th>
#       <th id="T_0586e_level0_col0" class="col_heading level0 col0" >manana</th>
#       <th id="T_0586e_level0_col1" class="col_heading level0 col1" >noche</th>
#       <th id="T_0586e_level0_col2" class="col_heading level0 col2" >tarde</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >OPERA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0586e_level0_row0" class="row_heading level0 row0" >Aerolineas Argentinas</th>
#       <td id="T_0586e_row0_col0" class="data row0 col0" >6.290832</td>
#       <td id="T_0586e_row0_col1" class="data row0 col1" >14.349040</td>
#       <td id="T_0586e_row0_col2" class="data row0 col2" >12.428571</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row1" class="row_heading level0 row1" >Aeromexico</th>
#       <td id="T_0586e_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_0586e_row1_col1" class="data row1 col1" >-2.756447</td>
#       <td id="T_0586e_row1_col2" class="data row1 col2" >43.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row2" class="row_heading level0 row2" >Air Canada</th>
#       <td id="T_0586e_row2_col0" class="data row2 col0" >21.879518</td>
#       <td id="T_0586e_row2_col1" class="data row2 col1" >18.328571</td>
#       <td id="T_0586e_row2_col2" class="data row2 col2" >28.904762</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row3" class="row_heading level0 row3" >Air France</th>
#       <td id="T_0586e_row3_col0" class="data row3 col0" >13.000000</td>
#       <td id="T_0586e_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_0586e_row3_col2" class="data row3 col2" >1.334270</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row4" class="row_heading level0 row4" >Alitalia</th>
#       <td id="T_0586e_row4_col0" class="data row4 col0" >3.837662</td>
#       <td id="T_0586e_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_0586e_row4_col2" class="data row4 col2" >7.428571</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row5" class="row_heading level0 row5" >American Airlines</th>
#       <td id="T_0586e_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_0586e_row5_col1" class="data row5 col1" >0.277411</td>
#       <td id="T_0586e_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row6" class="row_heading level0 row6" >Austral</th>
#       <td id="T_0586e_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_0586e_row6_col1" class="data row6 col1" >2.833333</td>
#       <td id="T_0586e_row6_col2" class="data row6 col2" >9.181818</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row7" class="row_heading level0 row7" >Avianca</th>
#       <td id="T_0586e_row7_col0" class="data row7 col0" >9.031088</td>
#       <td id="T_0586e_row7_col1" class="data row7 col1" >-0.415459</td>
#       <td id="T_0586e_row7_col2" class="data row7 col2" >20.986339</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row8" class="row_heading level0 row8" >British Airways</th>
#       <td id="T_0586e_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_0586e_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_0586e_row8_col2" class="data row8 col2" >7.560976</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row9" class="row_heading level0 row9" >Copa Air</th>
#       <td id="T_0586e_row9_col0" class="data row9 col0" >0.304609</td>
#       <td id="T_0586e_row9_col1" class="data row9 col1" >0.476103</td>
#       <td id="T_0586e_row9_col2" class="data row9 col2" >-1.041825</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row10" class="row_heading level0 row10" >Delta Air</th>
#       <td id="T_0586e_row10_col0" class="data row10 col0" >40.000000</td>
#       <td id="T_0586e_row10_col1" class="data row10 col1" >-0.329577</td>
#       <td id="T_0586e_row10_col2" class="data row10 col2" >59.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row11" class="row_heading level0 row11" >Gol Trans</th>
#       <td id="T_0586e_row11_col0" class="data row11 col0" >-5.003922</td>
#       <td id="T_0586e_row11_col1" class="data row11 col1" >8.650485</td>
#       <td id="T_0586e_row11_col2" class="data row11 col2" >22.290179</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row12" class="row_heading level0 row12" >Grupo LATAM</th>
#       <td id="T_0586e_row12_col0" class="data row12 col0" >9.088274</td>
#       <td id="T_0586e_row12_col1" class="data row12 col1" >10.843851</td>
#       <td id="T_0586e_row12_col2" class="data row12 col2" >8.906409</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row13" class="row_heading level0 row13" >Iberia</th>
#       <td id="T_0586e_row13_col0" class="data row13 col0" >6.333333</td>
#       <td id="T_0586e_row13_col1" class="data row13 col1" >nan</td>
#       <td id="T_0586e_row13_col2" class="data row13 col2" >3.595588</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row14" class="row_heading level0 row14" >JetSmart SPA</th>
#       <td id="T_0586e_row14_col0" class="data row14 col0" >4.381395</td>
#       <td id="T_0586e_row14_col1" class="data row14 col1" >9.659091</td>
#       <td id="T_0586e_row14_col2" class="data row14 col2" >9.404187</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row15" class="row_heading level0 row15" >K.L.M.</th>
#       <td id="T_0586e_row15_col0" class="data row15 col0" >-1.863309</td>
#       <td id="T_0586e_row15_col1" class="data row15 col1" >nan</td>
#       <td id="T_0586e_row15_col2" class="data row15 col2" >5.250000</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row16" class="row_heading level0 row16" >Lacsa</th>
#       <td id="T_0586e_row16_col0" class="data row16 col0" >4.880435</td>
#       <td id="T_0586e_row16_col1" class="data row16 col1" >nan</td>
#       <td id="T_0586e_row16_col2" class="data row16 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row17" class="row_heading level0 row17" >Latin American Wings</th>
#       <td id="T_0586e_row17_col0" class="data row17 col0" >22.385000</td>
#       <td id="T_0586e_row17_col1" class="data row17 col1" >29.347603</td>
#       <td id="T_0586e_row17_col2" class="data row17 col2" >21.538776</td>
#     </tr>
#     <tr>
#       <th id="T_0586e_level0_row18" class="row_heading level0 row18" >Oceanair Linhas Aereas</th>
#       <td id="T_0586e_row18_col0" class="data row18 col0" >nan</td>
#       <td id="T_0586e_row18_col1" clas

# %%
scl_flt.pivot_table(values = "dif_min",index="OPERA",columns="temporada_alta",aggfunc=(np.mean)).style.applymap(highlight)
# Out:
# <style type="text/css">
# #T_4e624_row0_col0, #T_4e624_row1_col0, #T_4e624_row1_col1, #T_4e624_row3_col0, #T_4e624_row3_col1, #T_4e624_row4_col0, #T_4e624_row4_col1, #T_4e624_row5_col0, #T_4e624_row5_col1, #T_4e624_row6_col0, #T_4e624_row8_col0, #T_4e624_row9_col0, #T_4e624_row9_col1, #T_4e624_row10_col0, #T_4e624_row10_col1, #T_4e624_row11_col1, #T_4e624_row12_col0, #T_4e624_row13_col0, #T_4e624_row13_col1, #T_4e624_row14_col0, #T_4e624_row14_col1, #T_4e624_row15_col0, #T_4e624_row15_col1, #T_4e624_row16_col0, #T_4e624_row16_col1, #T_4e624_row18_col0, #T_4e624_row18_col1, #T_4e624_row21_col0, #T_4e624_row21_col1, #T_4e624_row22_col0, #T_4e624_row22_col1 {
#   color: green;
# }
# #T_4e624_row0_col1, #T_4e624_row6_col1, #T_4e624_row7_col0, #T_4e624_row7_col1, #T_4e624_row8_col1, #T_4e624_row11_col0, #T_4e624_row12_col1 {
#   color: black;
# }
# #T_4e624_row2_col0, #T_4e624_row2_col1, #T_4e624_row17_col0, #T_4e624_row17_col1, #T_4e624_row19_col0, #T_4e624_row19_col1, #T_4e624_row20_col0, #T_4e624_row20_col1 {
#   color: red;
# }
# </style>
# <table id="T_4e624">
#   <thead>
#     <tr>
#       <th class="index_name level0" >temporada_alta</th>
#       <th id="T_4e624_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4e624_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >OPERA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e624_level0_row0" class="row_heading level0 row0" >Aerolineas Argentinas</th>
#       <td id="T_4e624_row0_col0" class="data row0 col0" >9.861351</td>
#       <td id="T_4e624_row0_col1" class="data row0 col1" >10.362657</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row1" class="row_heading level0 row1" >Aeromexico</th>
#       <td id="T_4e624_row1_col0" class="data row1 col0" >-2.639344</td>
#       <td id="T_4e624_row1_col1" class="data row1 col1" >-2.168224</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row2" class="row_heading level0 row2" >Air Canada</th>
#       <td id="T_4e624_row2_col0" class="data row2 col0" >16.466844</td>
#       <td id="T_4e624_row2_col1" class="data row2 col1" >35.829787</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row3" class="row_heading level0 row3" >Air France</th>
#       <td id="T_4e624_row3_col0" class="data row3 col0" >0.366935</td>
#       <td id="T_4e624_row3_col1" class="data row3 col1" >3.727273</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row4" class="row_heading level0 row4" >Alitalia</th>
#       <td id="T_4e624_row4_col0" class="data row4 col0" >4.342697</td>
#       <td id="T_4e624_row4_col1" class="data row4 col1" >7.382716</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row5" class="row_heading level0 row5" >American Airlines</th>
#       <td id="T_4e624_row5_col0" class="data row5 col0" >-0.773092</td>
#       <td id="T_4e624_row5_col1" class="data row5 col1" >2.297297</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row6" class="row_heading level0 row6" >Austral</th>
#       <td id="T_4e624_row6_col0" class="data row6 col0" >5.000000</td>
#       <td id="T_4e624_row6_col1" class="data row6 col1" >10.173913</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row7" class="row_heading level0 row7" >Avianca</th>
#       <td id="T_4e624_row7_col0" class="data row7 col0" >11.398970</td>
#       <td id="T_4e624_row7_col1" class="data row7 col1" >10.578667</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row8" class="row_heading level0 row8" >British Airways</th>
#       <td id="T_4e624_row8_col0" class="data row8 col0" >5.950355</td>
#       <td id="T_4e624_row8_col1" class="data row8 col1" >11.109375</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row9" class="row_heading level0 row9" >Copa Air</th>
#       <td id="T_4e624_row9_col0" class="data row9 col0" >0.234060</td>
#       <td id="T_4e624_row9_col1" class="data row9 col1" >0.173486</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row10" class="row_heading level0 row10" >Delta Air</th>
#       <td id="T_4e624_row10_col0" class="data row10 col0" >-0.606426</td>
#       <td id="T_4e624_row10_col1" class="data row10 col1" >1.761468</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row11" class="row_heading level0 row11" >Gol Trans</th>
#       <td id="T_4e624_row11_col0" class="data row11 col0" >13.616732</td>
#       <td id="T_4e624_row11_col1" class="data row11 col1" >8.910959</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row12" class="row_heading level0 row12" >Grupo LATAM</th>
#       <td id="T_4e624_row12_col0" class="data row12 col0" >9.064673</td>
#       <td id="T_4e624_row12_col1" class="data row12 col1" >10.296431</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row13" class="row_heading level0 row13" >Iberia</th>
#       <td id="T_4e624_row13_col0" class="data row13 col0" >3.208000</td>
#       <td id="T_4e624_row13_col1" class="data row13 col1" >6.660714</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row14" class="row_heading level0 row14" >JetSmart SPA</th>
#       <td id="T_4e624_row14_col0" class="data row14 col0" >7.446753</td>
#       <td id="T_4e624_row14_col1" class="data row14 col1" >7.430769</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row15" class="row_heading level0 row15" >K.L.M.</th>
#       <td id="T_4e624_row15_col0" class="data row15 col0" >0.325581</td>
#       <td id="T_4e624_row15_col1" class="data row15 col1" >3.455696</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row16" class="row_heading level0 row16" >Lacsa</th>
#       <td id="T_4e624_row16_col0" class="data row16 col0" >5.000000</td>
#       <td id="T_4e624_row16_col1" class="data row16 col1" >4.685714</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row17" class="row_heading level0 row17" >Latin American Wings</th>
#       <td id="T_4e624_row17_col0" class="data row17 col0" >23.861355</td>
#       <td id="T_4e624_row17_col1" class="data row17 col1" >26.677804</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row18" class="row_heading level0 row18" >Oceanair Linhas Aereas</th>
#       <td id="T_4e624_row18_col0" class="data row18 col0" >7.574766</td>
#       <td id="T_4e624_row18_col1" class="data row18 col1" >2.276923</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row19" class="row_heading level0 row19" >Plus Ultra Lineas Aereas</th>
#       <td id="T_4e624_row19_col0" class="data row19 col0" >32.733333</td>
#       <td id="T_4e624_row19_col1" class="data row19 col1" >30.105263</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row20" class="row_heading level0 row20" >Qantas Airways</th>
#       <td id="T_4e624_row20_col0" class="data row20 col0" >22.086614</td>
#       <td id="T_4e624_row20_col1" class="data row20 col1" >35.705882</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row21" class="row_heading level0 row21" >Sky Airline</th>
#       <td id="T_4e624_row21_col0" class="data row21 col0" >8.347540</td>
#       <td id="T_4e624_row21_col1" class="data row21 col1" >7.650370</td>
#     </tr>
#     <tr>
#       <th id="T_4e624_level0_row22" class="row_heading level0 row22" >United Airlines</th>
#       <td id="T_4e624_row22_col0" class="data row22 col0" >-3.169643</td>
#       <td id="T_4e624_row22_col1" class="data row22 col1" >0.792793</td>
#     </tr>
#   </tbody>
# </table>

# %%
tbl1 = scl_flt.pivot_table(values = "dif_min",index="Des-I",aggfunc=(np.mean,"count")).sort_values(by="mean", ascending=False)

# %%
tbl1[tbl1["count"]>10]
# Out:
#        count       mean
# Des-I
# YSSY     195  26.835897
# YMML      38  19.631579
# SAAR     136  19.022059
# NZAA     361  18.246537
# CYYZ     283  15.766784
# SAME    1625  15.512615
# SANT      38  14.263158
# SANU      35  14.142857
# SBGL    1434  14.135983
# MDPC      54  14.092593
# SLVR     120  14.066667
# SACO    1023  13.811339
# KLAX     155  13.264516
# SGAS     232  12.969828
# KMCO      34  12.852941
# KJFK     383  12.456919
# SKBO    1604  12.239401
# SABE    3094  11.890110
# SPJC    5270  11.736243
# SCIP     452  11.617257
# SBGR    3570  11.608683
# SAEZ    3240  11.472531
# SCJO     259  10.444015
# SUMU    1066  10.400563
# SEGU     423  10.063830
# LEMD     894   9.463087
# SCCI    2105   9.101663
# KMIA    1015   9.050246
# SCBA     843   8.972716
# SCTE    4357   8.868028
# SLLP     209   8.741627
# SCDA    3747   8.625567
# SCIE    3995   8.392240
# SCSE    2410   8.144813
# SCQP    2583   8.106078
# SAZN      37   8.000000
# SCVD     753   7.982736
# SBFL     162   7.703704
# EGLL     205   7.560976
# MMUN      63   7.365079
# SCAT    1780   7.154494
# SCAR    2436   7.143678
# SCFA    5787   7.023155
# SCPQ     235   6.212766
# SCCF    5145   5.970262
# LIRF     259   5.293436
# SCNT      79   4.518987
# MMMX     700   3.175714
# LFPG     359   1.660167
# MPTO    1850   0.214054
# KATL     358   0.114525
# KDFW     357  -1.081232
# KIAH     335  -1.856716

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(scl_flt,x="dif_min")
# Out:
# <AxesSubplot:xlabel='dif_min', ylabel='Count'>
